# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20, 15)
import seaborn as sns
import h5py

# %% [markdown]
# ## Effective Pressure

# %%
effective_pressure_file = h5py.File('effective_pressure_subset_RD0000.hdf5')
p_eff_x = np.array(effective_pressure_file['p_eff_x'][:])
p_eff_y = np.array(effective_pressure_file['p_eff_y'][:])
p_eff_z = np.array(effective_pressure_file['p_eff_z'][:])
density = np.array(effective_pressure_file['density'][:])
norm = np.sqrt(np.square(p_eff_x) + np.square(p_eff_y) + np.square(p_eff_z))

# %%
effective_pressure = pd.DataFrame(
    {'p_eff_x': p_eff_x,
     'p_eff_y': p_eff_y,
     'p_eff_z': p_eff_z,
     'norm': norm,
     'density': density,
     'lognorm': np.log10(norm),
     'logdensity': np.log10(density)
    }
)
effective_pressure.describe()
# Out:
#             density   logdensity      lognorm          norm       p_eff_x  \
# count  1.000000e+03  1000.000000  1000.000000  1.000000e+03  1.000000e+03
# mean   1.396785e-30   -30.266094         -inf  6.971849e-18  1.161479e-18
# std    3.650807e-30     0.504014          NaN  4.031362e-17  6.968793e-18
# min    8.313517e-32   -31.080215         -inf  0.000000e+00  0.000000e+00
# 25%    2.387455e-31   -30.622065         -inf  0.000000e+00  0.000000e+00
# 50%    4.623760e-31   -30.335005   -20.890314  1.287319e-21  0.000000e+00
# 75%    9.613181e-31   -30.017148   -18.499011  3.169486e-19  5.457661e-22
# max    4.400653e-29   -28.356483   -15.256468  5.540288e-16  1.065163e-16
#
#             p_eff_y       p_eff_z
# count  1.000000e+03  1.000000e+03
# mean   2.344549e-18  5.743709e-18
# std    1.760966e-17  3.571138e-17
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    0.000000e+00  2.724107e-20
# max    2.508175e-16  4.945549e-16

# %%
effective_pressure.plot.scatter(x='density', y='p_eff_x', loglog=True, ylim=[10e-25,10e-14], fontsize=20)

# %%
effective_pressure.plot.scatter(x='density', y='p_eff_y', loglog=True, ylim=[10e-25,10e-14], fontsize=20)

# %%
effective_pressure.plot.scatter(x='density', y='p_eff_z', loglog=True, ylim=[10e-25,10e-14], fontsize=20)

# %%
effective_pressure.plot.scatter(x='density', y='norm', loglog=True, ylim=[10e-25,10e-14], fontsize=20)
